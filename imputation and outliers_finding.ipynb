# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/IPL_Matches_2008_2022.csv")
data.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
data.shape
# Out:
# (950, 20)

# %%
data.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
sns.histplot(data['Margin'])
plt.show()

# %%
skewness=data['Margin'].skew()
print(skewness)
# Out:
# 2.6535823950532107

# %%
data['Margin'].fillna(data['Margin'].median(),inplace=True)
data.head()
# Out:
# <ipython-input-8-dd822e59a779>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Margin'].fillna(data['Margin'].median(),inplace=True)
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
# ...

# %%
data.method.value_counts()
# Out:
# method
# D/L    19
# Name: count, dtype: int64

# %%
#drop missing values
dropped_data=data.dropna(subset=['method'])
dropped_data.head()
# Out:
#           ID       City        Date Season MatchNumber  \
# 282  1136592      Delhi  2018-05-02   2018          32
# 296  1136578    Kolkata  2018-04-21   2018          18
# 308  1136566     Jaipur  2018-04-11   2018           6
# 316  1082648  Bangalore  2017-05-17   2017  Eliminator
# 383   980999  Bangalore  2016-05-18   2016          50
#
#                            Team1                  Team2  \
# 282             Delhi Daredevils       Rajasthan Royals
# 296        Kolkata Knight Riders        Kings XI Punjab
# 308             Rajasthan Royals       Delhi Daredevils
# 316          Sunrisers Hyderabad  Kolkata Knight Riders
# 383  Royal Challengers Bangalore        Kings XI Punjab
#
#                       Venue             TossWinner TossDecision SuperOver  \
# 282    Arun Jaitley Stadium       Rajasthan Royals        field         N
# 296            Eden Gardens        Kings XI Punjab        field         N
# ...

# %%
dropped_data.shape
# Out:
# (19, 20)

# %%
#data.drop('method', axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin               0
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
data.shape
# Out:
# (950, 20)

# %% [markdown]
# #handling inconsistence and outliers

# %%
data['Margin']
# Out:
# 0        7.0
# 1        7.0
# 2       14.0
# 3        7.0
# 4        5.0
#        ...
# 945      5.0
# 946      5.0
# 947      9.0
# 948     33.0
# 949    140.0
# Name: Margin, Length: 950, dtype: float64

# %%
sns.boxplot(data['Margin'])
# Out:
# <Axes: ylabel='Margin'>

# %%
plt.hist(data['Margin'])
plt.xlabel("margin")
plt.ylabel("frequency")
plt.title('Distributions of margins')
plt.show()

# %%
data.Margin.value_counts()
# Out:
# Margin
# 6.0      114
# 7.0      113
# 5.0       98
# 8.0       93
# 4.0       62
#         ...
# 118.0      1
# 146.0      1
# 91.0       1
# 52.0       1
# 140.0      1
# Name: count, Length: 94, dtype: int64

# %%
#outlier finding by using IQR method

q1=data['Margin'].quantile(0.25)
q3=data['Margin'].quantile(0.75)

IQR=q3-q1

# %%
outliers=data[data['Margin'] < (q1-1.5*IQR)]
outliers=pd.concat([outliers, (data[data['Margin'] > q3+1.5 * IQR])])
outliers
# Out:
#           ID         City        Date   Season MatchNumber  \
# 13   1304107         Pune  2022-05-14     2022          61
# 14   1304106       Mumbai  2022-05-13     2022          60
# 17   1304103         Pune  2022-05-10     2022          57
# 18   1304102  Navi Mumbai  2022-05-09     2022          56
# 19   1304101  Navi Mumbai  2022-05-08     2022          55
# ..       ...          ...         ...      ...         ...
# 895   336019   Chandigarh  2008-05-28  2007/08          56
# 911   336023       Jaipur  2008-05-17  2007/08          39
# 931   336000       Jaipur  2008-05-01  2007/08          18
# 940   335991   Chandigarh  2008-04-25  2007/08          10
# 949   335982    Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 13         Kolkata Knight Riders          Sunrisers Hyderabad
# 14                  Punjab Kings  Royal Challengers Bangalore
# 17                Gujarat Titans         Lucknow Super Giants
# ...

# %%
outliers['Margin']
# Out:
# 13      54.0
# 14      54.0
# 17      62.0
# 18      52.0
# 19      91.0
#        ...
# 895     41.0
# 911     65.0
# 931     45.0
# 940     66.0
# 949    140.0
# Name: Margin, Length: 131, dtype: float64

# %%
outliers.shape[0]
# Out:
# 131

# %%
x=data[data['Margin'] < (q1-1.5*IQR)] | data[data['Margin'] > (q3+1.5*IQR)]
x.shape
# Out:
# (131, 20)

# %%
#finding the outilers by using zscore

z_scores=np.abs(data['Margin']  -  data['Margin'].mean())/data['Margin'].std()
outliers_2=z_scores[z_scores < -3] | z_scores[z_scores > 3]
outliers_2
# Out:
# <ipython-input-25-dbced063bfc6>:4: FutureWarning: Operation between non boolean Series with different indexes will no longer return a boolean result in a future version. Cast both Series to object type to maintain the prior behavior.
#   outliers_2=z_scores[z_scores < -3] | z_scores[z_scores > 3]
# 19     False
# 80     False
# 147    False
# 166    False
# 188    False
# 242    False
# 273    False
# 329    False
# 346    False
# 364    False
# 383    False
# 388    False
# 396    False
# 453    False
# 468    False
# 544    False
# 597    False
# 604    False
# 605    False
# 629    False
# 709    False
# 713    False
# 729    False
# 826    False
# 877    False
# 887    False
# 894    False
# 949    False
# Name: Margin, dtype: bool

# %%
z_scores
# Out:
# 0      0.460582
# 1      0.460582
# 2      0.134432
# 3      0.460582
# 4      0.553767
#          ...
# 945    0.553767
# 946    0.553767
# 947    0.367396
# 948    0.750830
# 949    5.736258
# Name: Margin, Length: 950, dtype: float64

# %%
outliers_2.shape[0]
# Out:
# 28
